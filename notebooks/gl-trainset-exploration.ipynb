# %% [markdown]
# # Exploration of the trainset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
ls ../shopee/data/shopee-product-matching/
# Out:
# ls: ../shopee/data/shopee-product-matching/: No such file or directory

# %%
y_train = pd.read_csv('../raw_data/shopee-product-matching/train.csv')
y_train.head(10)
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2  train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3  train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4  train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
# 5  train_2464356923  0013e7355ffc5ff8fb1ccad3e42d92fe.jpg  bbd097a7870f4a50
# 6  train_1802986387  00144a49c56599d45354a1c28104c039.jpg  f815c9bb833ab4c8
# 7  train_1806152124  0014f61389cbaa687a58e38a97b6383d.jpg  eea7e1c0c04da33d
# 8    train_86570404  0019a3c6755a194cb2e2c12bfc63972e.jpg  ea9af4f483249972
# 9   train_831680791  001be52b2beec40ddc1d2d7fc7a68f08.jpg  e1ce953d1a70618f
#
#                                                title  label_group
# 0                          Paper Bag Victoria Secret    249114794
# ...

# %%
ls ../shopee/data/shopee-product-matching/train_images/
# Out:
# ls: ../shopee/data/shopee-product-matching/train_images/: No such file or directory

# %%
for image_adresse in y_train.image.head(5):
    print(image_adresse)
    image = img.imread(f'../raw_data/shopee-product-matching/train_images/{image_adresse}')
    plt.imshow(image)
# Out:
# 0000a68812bc7e98c42888dfb1c07da0.jpg
# 00039780dfc94d01db8676fe789ecd05.jpg
# 000a190fdd715a2a36faed16e2c65df7.jpg
# 00117e4fc239b1b641ff08340b429633.jpg
# 00136d1cf4edede0203f32f05f660588.jpg

# %%
y_train.head(10)
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2  train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3  train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4  train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
# 5  train_2464356923  0013e7355ffc5ff8fb1ccad3e42d92fe.jpg  bbd097a7870f4a50
# 6  train_1802986387  00144a49c56599d45354a1c28104c039.jpg  f815c9bb833ab4c8
# 7  train_1806152124  0014f61389cbaa687a58e38a97b6383d.jpg  eea7e1c0c04da33d
# 8    train_86570404  0019a3c6755a194cb2e2c12bfc63972e.jpg  ea9af4f483249972
# 9   train_831680791  001be52b2beec40ddc1d2d7fc7a68f08.jpg  e1ce953d1a70618f
#
#                                                title  label_group
# 0                          Paper Bag Victoria Secret    249114794
# ...

# %%
y_train[y_train['label_group']==2937985045]
# Out:
#              posting_id                                 image  \
# 1      train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg
# 18683  train_3423213080  8cbe4bf9706bc177fd61071ef776be8c.jpg
#
#             image_phash                                              title  \
# 1      af3f9460c2838f0f  Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...
# 18683  bfc6d01bc72c1d30  Double Tape VHB 3M ORIGINAL 12mm x 4.5mm Busa ...
#
#        label_group
# 1       2937985045
# 18683   2937985045

# %%
image = img.imread(f'../raw_data/shopee-product-matching/train_images/f83b49a86a0ee8592e3bf0204da3fbdf.jpg')
plt.imshow(image)

# %%
image = img.imread(f'../raw_data/shopee-product-matching/train_images/0000a68812bc7e98c42888dfb1c07da0.jpg')
plt.imshow(image)

# %%
y_train[y_train['label_group']==2937985045]
# Out:
#              posting_id                                 image  \
# 1      train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg
# 18683  train_3423213080  8cbe4bf9706bc177fd61071ef776be8c.jpg
#
#             image_phash                                              title  \
# 1      af3f9460c2838f0f  Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...
# 18683  bfc6d01bc72c1d30  Double Tape VHB 3M ORIGINAL 12mm x 4.5mm Busa ...
#
#        label_group
# 1       2937985045
# 18683   2937985045

# %%
image = img.imread(f'../raw_data/shopee-product-matching/train_images/00039780dfc94d01db8676fe789ecd05.jpg')
plt.imshow(image)

# %%
image = img.imread(f'../raw_data/shopee-product-matching/train_images/8cbe4bf9706bc177fd61071ef776be8c.jpg')
plt.imshow(image)

# %%
from PIL import Image

# %%
img=Image.open("../raw_data/shopee-product-matching/train_images/00039780dfc94d01db8676fe789ecd05.jpg")

# %%
img.size
# Out:
# (1000, 1000)

# %%
images = [image for image in y_train['image']]

# %%
size_img = []
for image in images:
    img=Image.open(f"../raw_data/shopee-product-matching/train_images/{image}").size
    size_img.append(img)
size_img
# Out:
# [(1024, 1024),
#  (1000, 1000),
#  (640, 640),
#  (640, 640),
#  (756, 756),
#  (640, 640),
#  (640, 640),
#  (640, 640),
#  (300, 300),
#  (700, 700),
#  (700, 700),
#  (1000, 1000),
#  (1000, 1000),
#  (449, 449),
#  (640, 640),
#  (640, 640),
#  (1024, 1024),
#  (800, 800),
#  (314, 314),
#  (595, 595),
#  (4500, 4501),
#  (700, 700),
#  (604, 604),
#  (665, 665),
#  (700, 700),
#  (640, 640),
#  (1024, 1024),
#  (1024, 1024),
#  (700, 700),
#  (700, 700),
#  (640, 640),
#  (640, 640),
#  (800, 800),
#  (640, 640),
#  (640, 640),
#  (640, 640),
#  (1000, 1000),
#  (1000, 1000),
#  (720, 720),
#  (1024, 1024),
#  (1024, 1024),
#  (1024, 1024),
#  (640, 640),
#  (640, 640),
#  (1024, 1024),
#  (700, 700),
#  (699, 699),
#  (800, 800),
#  (640, 640),
#  (700, 700),
#  (640, 640),
#  (1024, 1024),
#  (1024, 1024),
#  (1024, 1024),
#  (800, 800),
#  (1024, 1024),
#  (640, 640),
#  (640, 640),
#  (1024, 1024),
#  (1024, 1024),
#  (700, 700),
#  (820, 820),
#  (640, 640),
#  (960, 960),
# ...

# %%
max(size_img)
# Out:
# (5000, 5000)

# %%
min(size_img)
# Out:
# (100, 100)

# %%
size_count = pd.DataFrame(size_img)
size_count
# Out:
#           0     1
# 0      1024  1024
# 1      1000  1000
# 2       640   640
# 3       640   640
# 4       756   756
# ...     ...   ...
# 34245   640   640
# 34246  1024  1024
# 34247   981   981
# 34248   800   800
# 34249   640   640
#
# [34250 rows x 2 columns]

# %%
size_count[size_count[0]<=256]
# Out:
#          0    1
# 134    225  225
# 166    200  200
# 359    227  227
# 362    225  225
# 722    225  225
# ...    ...  ...
# 33054  194  194
# 33258  225  225
# 33384  225  225
# 33506  225  225
# 34135  234  234
#
# [167 rows x 2 columns]

# %%
for x in size_img:
    if x[0]!=x[1]:
        print(x)
        print('not squarred')
# Out:
# (4500, 4501)
# not squarred
# (530, 640)
# not squarred
# (640, 638)
# not squarred
# (640, 639)
# not squarred
# (480, 640)
# not squarred
# (498, 640)
# not squarred
# (311, 640)
# not squarred
# (640, 493)
# not squarred
# (480, 640)
# not squarred
# (512, 640)
# not squarred
# (640, 480)
# not squarred
# (595, 640)
# not squarred
# (480, 640)
# not squarred
# (444, 640)
# not squarred
# (481, 640)
# not squarred
# (640, 597)
# not squarred
# (640, 635)
# not squarred
# (480, 640)
# not squarred
# (424, 640)
# not squarred
# (1000, 1001)
# not squarred
# (546, 640)
# not squarred
# (480, 640)
# not squarred
# (360, 640)
# not squarred
# (640, 479)
# not squarred
# (640, 480)
# not squarred
# (1001, 1000)
# not squarred
# (640, 330)
# not squarred
# (481, 640)
# not squarred
# (434, 402)
# not squarred
# (1000, 1001)
# not squarred
# (640, 518)
# not squarred
# (480, 640)
# not squarred
# (640, 639)
# not squarred
# (640, 636)
# not squarred
# (4168, 4167)
# not squarred
# ...

# %%
#y_train['size_img'][] = Image.open(f"../raw_data/shopee-product-matching/train_images/{y_train.image}").size

# %%
#images = [image for image in y_train['image']]
#for image in images:
#    img_shape = []
#    image_path =  f'{image}'
#    filename = os.path.abspath(os.path.join('../raw_data/train_images', image_path))
#    img = io.imread(filename)
#    x = img.shape
#    img_shape.append(x)
